# %%
import pandas as pd

# %%
filepath = "Resources/input/emissions.csv"

# %%
df=pd.read_csv(filepath)
df=df.set_index("State")
df.head()
# Out:
#              2008        2009        2010        2011        2012        2013  \
# State
# AL     139.666603  120.020443  132.722932  129.812612  123.039324  120.732885
# AK      39.435905   37.788246   38.729384   38.585774   38.039447   35.975289
# AZ     102.125070   93.252826   95.204594   93.282044   91.256850   95.060822
# AR      64.059757   61.367031   65.723403   67.168798   65.940126   68.354108
# CA     379.480916  366.184902  360.953079  346.864178  351.496006  354.219000
#
#              2014        2015        2016        2017
# State
# AL     123.080771  120.012608  114.872696  109.018634
# AK      35.171091   36.067852   34.739390   34.295441
# AZ      93.120620   90.856296   86.971877   86.137839
# AR      68.985869   59.176044   62.319791   64.277677
# CA     351.477053  359.290429  359.261859  360.913489

# %%
html=df.to_html()
html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>2008</th>\n      <th>2009</th>\n      <th>2010</th>\n      <th>2011</th>\n      <th>2012</th>\n      <th>2013</th>\n      <th>2014</th>\n      <th>2015</th>\n      <th>2016</th>\n      <th>2017</th>\n    </tr>\n    <tr>\n      <th>State</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>AL</th>\n      <td>139.666603</td>\n      <td>120.020443</td>\n      <td>132.722932</td>\n      <td>129.812612</td>\n      <td>123.039324</td>\n      <td>120.732885</td>\n      <td>123.080771</td>\n      <td>120.012608</td>\n      <td>114.872696</td>\n      <td>109.018634</td>\n    </tr>\n    <tr>\n      <th>AK</th>\n      <td>39.435905</td>\n      <td>37.788246</td>\n      <td>38.729384</td>\n      <td>38.585774<
# ...

# %%
text_file=open("index.html", "w")
text_file.write(html)
text_file.close()
